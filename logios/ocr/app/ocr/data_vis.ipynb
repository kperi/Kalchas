# %%
import matplotlib.pyplot as plt
import cv2 
import os 
import json


image_path = "/Users/konstantinosperifanos/Downloads/pages/TODO/ΑΑ/Φιλολογική πανδαισία τα υποθαλάσσια άνθη. Ευφύια των αγρίων της Αμερικής. Αίτια και αποτέλεσμα./1_2/023.png"

image_path = "/Users/konstantinosperifanos/Downloads/pages/TODO/ΑΑ/Αλληλογραφία/0/017.png"

j_file = image_path.replace( ".png", ".json")

# %%
job = json.load(open(j_file))
img = cv2.imread(image_path)
plt.imshow(img)
print(job['text'][0])
# Out:
# δνρεκοὶ ἠσεσςο;

# %%
# !pwd
# Out:
# /Users/konstantinosperifanos/code/projects/postdoc/lib

# %%
import pandas as pd
import numpy as np 
stressed_chars = pd.read_csv("../st/chars_stressed.csv")
stressed_chars.columns  = ["_", "char", "freq"]

stressed_chars = stressed_chars["char"].values
stressed_chars = np.append( stressed_chars,  np.zeros(70-len(stressed_chars), dtype=str) ) 
stressed_chars.reshape(10,7)
# Out:
# array([['Ἀ', 'ἄ', 'Ἄ', 'ἂ', 'ἁ', 'ἅ', 'ά'],
#        ['ὰ', 'ᾶ', 'ᾳ', 'ἐ', 'Ἐ', 'ἔ', 'ἑ'],
#        ['Ἑ', 'ἕ', 'έ', 'ὲ', 'ζ', 'ἠ', 'ἤ'],
#        ['ἢ', 'ἦ', 'ἡ', 'Ἡ', 'ἥ', 'ή', 'ῄ'],
#        ['ὴ', 'ῆ', 'ῇ', 'ῃ', 'ἰ', 'Ἰ', 'ἴ'],
#        ['ἶ', 'ἱ', 'ἵ', 'ἳ', 'ἷ', 'ί', 'ὶ'],
#        ['ῖ', 'ὀ', 'ὄ', 'ὁ', 'Ὁ', 'ὅ', 'ό'],
#        ['ὸ', 'Ῥ', 'ὐ', 'ὔ', 'ὖ', 'ὑ', 'ὕ'],
#        ['ύ', 'ὺ', 'ῦ', 'ὠ', 'ὡ', 'ὥ', 'ὧ'],
#        ['ώ', 'ὼ', 'ῶ', 'ῷ', 'ῳ', '', '']], dtype=object)
